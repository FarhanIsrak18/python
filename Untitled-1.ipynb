# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import __version__
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# To display plots inside notebook
# %matplotlib inline

#sns.get_dataset_names()

water = pd.read_csv (r'D:\pip_lab\water_potability.csv')
#water
#sns.lineplot(x="Chloramines", y="Sulfate", data=water)
#print(water.describe())
#print(water.data)
water.keys()
#print("water data size is {}".format(water.data.shape))
water.shape[1]
#print(__version__)
#print(water.feature_name)

feature_water = water.drop('Potability', axis='columns')#features 
target_water = water['Potability']
target_water
#water_df['Potability'] = water.target
#print(water.feature_names)
#print(water.keys())
#water = pd.DataFrame(water.data, columns=water.Potability)
#water_df
#target_water['Potability'] = water.target
#target_water.isnull().sum()
water.isnull().sum()# Return number of missing values for each column

water.replace(0, np.nan, inplace=True)
feature_water.replace(0, np.nan, inplace=True)
target_water.replace(0, np.nan, inplace=True)
water
water.isnull().sum()/len(water)*100 # % of missing value of each column

with sns.axes_style('darkgrid'):
 sns.displot(feature_water['Chloramines'], bins=30, color='green')
 plt.title("Data distribution of feature variables ");#data distribution of chloramines

# corr() to calculate the correlation between variables
correlation_matrix = water.corr().round(2)
# changing the figure size
plt.figure(figsize = (10, 7))
# "annot = True" to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True);

 # Steps to remove redundant values
# Return a array filled with zeros
mask = np.zeros_like(correlation_matrix)
# Return the indices for the upper-triangle of array
mask[np.triu_indices_from(mask)] = True
# changing the figure size
plt.figure(figsize = (10, 7))
# "annot = True" to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True, mask=mask);

plt.figure(figsize=(14,10))
# Relatiosnship with 'CRIM' and 'MEDV'
plt.subplot(2, 3, 1)
sns.scatterplot(x=water['ph'], y=water['Potability'])
plt.title("ph and Potability")
# Relatiosnship with 'RM' and 'MEDV'
plt.subplot(2, 3, 2)
sns.scatterplot(x=water['Hardness'], y=water['Potability'])
plt.title("Hardness and Potability", color='green')
# Relatiosnship with 'PTRATIO' and 'MEDV'
plt.subplot(2, 3, 3)
sns.scatterplot(x=water['Solids'], y=water['Potability'])
plt.title("Solids and Potability")
# Relatiosnship with 'B' and 'MEDV'
plt.subplot(2, 3, 4)
sns.scatterplot(x=water['Chloramines'], y=water['Potability'])
plt.title("Chloramines and Potability")
# Relatiosnship with 'LSTAT' and 'MEDV'
plt.subplot(2, 3, 5)
sns.scatterplot(x=water['Sulfate'], y=water['Potability']);
plt.title("Sulfate and Potability", color='green');

plt.subplot(2, 3, 5)
sns.scatterplot(x=water['Conductivity'], y=water['Potability']);
plt.title("LSTAT and Potability", color='green');

plt.subplot(2, 3, 5)
sns.scatterplot(x=water['Organic_carbon'], y=water['Potability']);
plt.title("LSTAT and Potability", color='green');

plt.subplot(2, 3, 5)
sns.scatterplot(x=water['Trihalomethanes'], y=water['Potability']);
plt.title("trihalomethanes and Potability", color='green');

X=feature_water
Y=target_water
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)


#   Create LinearRegression Instance
#lrm = LinearRegression()
#   Fit data on to the model
#lrm.fit(X_train, y_train)
#   Predict
#y_predicted = lrm.predict(X_test)



#   calculate r-squared values
#r2 = lrm.score(X_test, y_test)
#   calculate the difference between predicted and the test values. 
#rmse = (np.sqrt(mean_squared_error(y_test, y_predicted)))
#   print the both values
#print('-------------------------------------------')
#print('r-squared: {}'.format(r2))
#print('-------------------------------------------')
#print('root mean squared error: {}'.format(rmse))
#print('-------------------------------------------')
# Out:
# X_train shape:  (2620, 9)
# X_test shape:  (656, 9)
# y_train shape:  (2620,)
# y_test shape:  (656,)
